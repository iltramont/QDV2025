# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Load
data = pd.read_csv("20251201_QDV2025_001.csv")

# %%
data.head()
# Out:
#          NOME PROVINCIA (ISTAT) CODICE NUTS 3 2021  \
# 0                        Milano              ITC4C
# 1                 Bolzano/Bozen              ITH10
# 2                       Bologna              ITH55
# 3                          Roma              ITI43
# 4  Valle d'Aosta/Vallée d'Aoste              ITC20
#
#    CODICE PROVINCIA ISTAT (STORICO) DENOMINAZIONE CORRENTE  VALORE  \
# 0                                15                 Milano    75.1
# 1                                21                Bolzano    62.7
# 2                                37                Bologna    51.4
# 3                                58                   Roma    50.6
# 4                                 7                  Aosta    49.4
#
#                      INDICATORE                    UNITA' DI MISURA  \
# 0  Valore aggiunto per abitante  Migliaia di euro a valori correnti
# 1  Valore aggiunto per abitante  Migliaia di euro a valori correnti
# 2  Valore aggiunto per abitante  Migliaia di euro a valori correnti
# 3  Valore aggiunto per abitante  Migliaia di euro a valori correnti
# 4  Valore aggiunto per abitante  Migliaia di euro a valori correnti
#
#   ANNO DI RIFERIMENTO DEI DATI      FONTE
# 0               Stima sul 2025  Prometeia
# 1               Stima sul 2025  Prometeia
# 2               Stima sul 2025  Prometeia
# 3               Stima sul 2025  Prometeia
# 4               Stima sul 2025  Prometeia

# %%
data.rename(columns={'DENOMINAZIONE CORRENTE': 'PROVINCIA'}, inplace=True)

# %%
print(f"Numero indicatori presi in esame: {len(data['INDICATORE'].unique())}")
print(f"Numero province esaminate: {len(data['PROVINCIA'].unique())}")
# Out:
# Numero indicatori presi in esame: 90
# Numero province esaminate: 107

# %%
# Verifica univocità
for c in data.columns[:4]:
    print(c, len(data[c].unique()))
# Out:
# NOME PROVINCIA (ISTAT) 107
# CODICE NUTS 3 2021 107
# CODICE PROVINCIA ISTAT (STORICO) 107
# PROVINCIA 107

# %%
tabella_province = data.iloc[:, :4]
tabella_province = tabella_province.drop_duplicates().reset_index(drop=True)
tabella_province.columns = ['NOME_ISTAT', 'COD_NUTS', 'COD_ISTAT', 'PROVINCIA']
display(tabella_province)
# Out:
#                        NOME_ISTAT COD_NUTS  COD_ISTAT              PROVINCIA
# 0                          Milano    ITC4C         15                 Milano
# 1                   Bolzano/Bozen    ITH10         21                Bolzano
# 2                         Bologna    ITH55         37                Bologna
# 3                            Roma    ITI43         58                   Roma
# 4    Valle d'Aosta/Vallée d'Aoste    ITC20          7                  Aosta
# ..                            ...      ...        ...                    ...
# 102                     Agrigento    ITG14         84              Agrigento
# 103                 Vibo Valentia    ITF64        102          Vibo Valentia
# 104                  Sud Sardegna   ITG2H         111           Sud Sardegna
# 105         Barletta-Andria-Trani    ITF48        110  Barletta-Andria-Trani
# 106                       Cosenza    ITF61         78                Cosenza
#
# [107 rows x 4 columns]

# %%
tabella_indicatori = data.iloc[:, 5:]
tabella_indicatori = tabella_indicatori.drop_duplicates().reset_index(drop=True)
tabella_indicatori.columns = ['INDICATORE', 'UNITA_MISURA', 'ANNO_RIFERIMENTO', 'FONTE']
display(tabella_indicatori)
# Out:
#                                            INDICATORE  \
# 0                        Valore aggiunto per abitante
# 1                            Trend del pil pro capite
# 2        Depositi bancari delle famiglie consumatrici
# 3   Retribuzione media annua dei lavoratori dipend...
# 4                Reddito medio disponibile pro capite
# ..                                                ...
# 85                                      Aree protette
# 86                    Spesa dei Comuni per la cultura
# 87        Amministratori comunali con meno di 40 anni
# 88                          Partecipazione elettorale
# 89                          Organizzazioni non profit
#
#                               UNITA_MISURA   ANNO_RIFERIMENTO  \
# 0       Migliaia di euro a valori correnti     Stima sul 2025
# 1                              Var % annua  Stima 2025 / 2024
# 2              In migliaia euro pro capite  Al 31 luglio 2025
# 3                                     Euro               2023
# 4                        Euro per abitante               2023
# ..                                     ...                ...
# 85                                    In %               2022
# 86  In euro pro capite per alcuni capitoli               2024
# 87                         In % sul totale               2024
# 88                      Valori percentuali               2025
# 89                     Per 10.000 abitanti               2022
#
#                                                 FONTE
# 0                                           Prometeia
# 1                             elab. su dati Prometeia
# 2                                      Banca d'italia
# 3   Istat - Elaborazioni su dati Inps - Osservator...
# 4   Istituto Tagliacarne - Stime provinciali degli...
# ..                                                ...
# 85                                          Bes Istat
# 86                    Elab. Tagliacarne su dati Siope
# 87  Istat su dati Anagrafe degli amministratori lo...
# 88                                          Bes Istat
# 89    Istat - Censimento sulle istituzioni non profit
#
# [90 rows x 4 columns]

# %%
tabella_punteggi = data[['PROVINCIA', 'INDICATORE', 'VALORE']]
display(tabella_punteggi)
# Out:
#                   PROVINCIA                    INDICATORE  VALORE
# 0                    Milano  Valore aggiunto per abitante    75.1
# 1                   Bolzano  Valore aggiunto per abitante    62.7
# 2                   Bologna  Valore aggiunto per abitante    51.4
# 3                      Roma  Valore aggiunto per abitante    50.6
# 4                     Aosta  Valore aggiunto per abitante    49.4
# ...                     ...                           ...     ...
# 9625  Barletta-Andria-Trani     Organizzazioni non profit    41.8
# 9626        Monza e Brianza     Organizzazioni non profit    40.9
# 9627                Caserta     Organizzazioni non profit    38.1
# 9628                 Napoli     Organizzazioni non profit    35.5
# 9629              Agrigento     Organizzazioni non profit    34.4
#
# [9630 rows x 3 columns]

# %%
# Save
if False:
    tabella_punteggi.to_csv("punteggi.csv", index=False)
    tabella_province.to_csv("province.csv", index=False)
    tabella_indicatori.to_csv("indicatori.csv", index=False)
